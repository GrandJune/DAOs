# %%
from Individual import Individual
from Reality import Reality
import matplotlib.pyplot as plt
import numpy as np

# %%
skill_num = 50
skill_mean = 1
skill_sigma = 1
sigma_list = np.arange(1, 3, 0.1)
skill_gap_list = []
for sigma in sigma_list:
    skill_gap = []
    for _ in range(1000):
        individual = Individual(skill_mean, sigma, skill_num)
        skill_gap.append(individual.skill_gap)
    skill_gap = sum(skill_gap)/len(skill_gap)
    skill_gap_list.append(skill_gap)
x = sigma_list
plt.plot(x, skill_gap_list, "k-")
# plt.savefig("search.jpg")
plt.title('Skill Gap Across Sigma')
plt.xlabel('Sigma')
plt.ylabel('Skill Gap (%)')
plt.show()
# if using the Normal distribution, the skill gap is a linear function of variance sigma;
# So they use the symmetric Dirichlet distribution in the Appendix;
# Normal distribution is just used for illustration;

# %%
skill_num = 50
skill_mean = 100
skill_sigma = 1
sigma_list = np.arange(1, 50, 1)
skill_gap_list = []
for sigma in sigma_list:
    skill_gap = []
    for _ in range(100):
        individual = Individual(skill_mean, sigma, skill_num)
        skill_gap.append(individual.skill_gap)
    skill_gap = sum(skill_gap)/len(skill_gap)
    skill_gap_list.append(skill_gap)
x = sigma_list
plt.plot(x, skill_gap_list, "k-")
# plt.savefig("search.jpg")
plt.title('Skill Gap Across Sigma')
plt.xlabel('Sigma')
plt.ylabel('Skill Gap (%)')
plt.show()
# if using the Normal distribution, the skill gap is a linear function of variance sigma;
# So they use the symmetric Dirichlet distribution in the Appendix;
# Normal distribution is just used for illustration;

# %%
skill_num = 50
skill_mean = 1
skill_sigma = 1
sigma_list = np.arange(1, 3, 0.1)
skill_gap_list = []
for sigma in sigma_list:
    skill_list = []
    for _ in range(1000):
        individual = Individual(skill_mean, sigma, skill_num)
        skill_list += individual.skills
        # skill_gap.append(individual.skill_gap)
    # skill_gap = sum(skill_gap)/len(skill_gap)
    # skill_gap_list.append(skill_gap)
plt.scatter(skill_list)
# plt.savefig("search.jpg")
plt.title('Skill Gap Across Sigma')
plt.xlabel('Sigma')
plt.ylabel('Skill Gap (%)')
plt.show()
# if using the Normal distribution, the skill gap is a linear function of variance sigma;
# So they use the symmetric Dirichlet distribution in the Appendix;
# Normal distribution is just used for illustration;
