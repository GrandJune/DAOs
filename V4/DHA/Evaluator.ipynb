# %%
import matplotlib.pyplot as plt
import pickle
import numpy as np
legend_properties = {'weight':'bold'}

# %%
data_folder = r"E:\data\dao-0310-23\V4_4\DHA_4"
dao_performance_file = data_folder + r"\dao_performance"
hierarchy_performance_file = data_folder + r"\hierarchy_performance"
autonomy_performance_file = data_folder + r"\autonomy_performance"

consensus_performance_file = data_folder + r"\dao_consensus_performance"
superior_performance_file = data_folder + r"\hierarchy_superior_performance"

dao_diversity_file = data_folder + r"\dao_diversity"
hierarchy_diversity_file = data_folder + r"\hierarchy_diversity"
autonomy_diversity_file = data_folder + r"\autonomy_diversity"

dao_variance_file = data_folder + r"\dao_variance"
hierarchy_variance_file = data_folder + r"\hierarchy_variance"
autonomy_variance_file = data_folder + r"\autonomy_variance"

dao_cv_file = data_folder + r"\dao_cv"
autonomy_cv_file = data_folder + r"\autonomy_cv"
hierarchy_cv_file = data_folder + r"\hierarchy_cv"

dao_entropy_file = data_folder + r"\dao_entropy"
autonomy_entropy_file = data_folder + r"\autonomy_entropy"
hierarchy_entropy_file = data_folder + r"\hierarchy_entropy"

dao_antagonism_file = data_folder + r"\dao_antagonism"
autonomy_antagonism_file = data_folder + r"\autonomy_antagonism"
hierarchy_antagonism_file = data_folder + r"\hierarchy_antagonism"

with open(dao_performance_file, 'rb') as infile:
    dao_performance = pickle.load(infile)
with open(hierarchy_performance_file, 'rb') as infile:
    hierarchy_performance = pickle.load(infile)
with open(autonomy_performance_file, 'rb') as infile:
    autonomy_performance = pickle.load(infile)

with open(dao_diversity_file, 'rb') as infile:
    dao_diversity = pickle.load(infile)
with open(hierarchy_diversity_file, 'rb') as infile:
    hierarchy_diversity = pickle.load(infile)
with open(autonomy_diversity_file, 'rb') as infile:
    autonomy_diversity = pickle.load(infile)

with open(consensus_performance_file, 'rb') as infile:
    consensus_performance = pickle.load(infile)
with open(superior_performance_file, 'rb') as infile:
    superior_performance = pickle.load(infile)

with open(dao_variance_file, 'rb') as infile:
    dao_variance = pickle.load(infile)
with open(hierarchy_variance_file, 'rb') as infile:
    hierarchy_variance = pickle.load(infile)
with open(autonomy_variance_file, 'rb') as infile:
    autonomy_variance = pickle.load(infile)

# Coefficient of Variation (CV)
with open(dao_cv_file, 'rb') as infile:
    dao_cv = pickle.load(infile)
with open(autonomy_cv_file, 'rb') as infile:
    autonomy_cv = pickle.load(infile)
with open(hierarchy_cv_file, 'rb') as infile:
    hierarchy_cv = pickle.load(infile)

# Entropy
with open(dao_entropy_file, 'rb') as infile:
    dao_entropy = pickle.load(infile)
with open(autonomy_entropy_file, 'rb') as infile:
    autonomy_entropy = pickle.load(infile)
with open(hierarchy_entropy_file, 'rb') as infile:
    hierarchy_entropy = pickle.load(infile)

# Antagonism
with open(dao_antagonism_file, 'rb') as infile:
    dao_antagonism = pickle.load(infile)
with open(autonomy_antagonism_file, 'rb') as infile:
    autonomy_antagonism = pickle.load(infile)
with open(hierarchy_antagonism_file, 'rb') as infile:
    hierarchy_antagonism = pickle.load(infile)

# %%
# Define more colors
# NUS two colors
nus_blue = "#003D7C"
nus_orange = "#EF7C00"
# Nature three colors
nature_orange = "#F16C23"
nature_blue = "#2B6A99"
nature_green = "#1B7C3D"
# Morandi six colors
morandi_blue = "#046586"
morandi_green =  "#28A9A1"
morandi_yellow = "#C9A77C"
morandi_orange = "#F4A016"
morandi_pink = "#F6BBC6"
morandi_red = "#E71F19"
morandi_purple = "#B08BEB"
# Others
shallow_grey = "#D3D4D3"
deep_grey = "#A6ABB6"

# %%
# Performance
x = range(len(dao_performance))
fig, ax = plt.subplots()
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)

num_markers = 6
# Calculate indices for marker positions
marker_positions = np.linspace(0, len(x) - 1, num=num_markers, dtype=int)

line_1 = ax.plot(x, dao_performance, "k-s", label="DAO", markevery=marker_positions)
line_2 = ax.plot(x, hierarchy_performance, "k-v", label="Hierarchy", markevery=marker_positions)
line_3 = ax.plot(x, autonomy_performance, "k-o", label="Autonomy (performance)", markevery=marker_positions)
plt.xlabel('Time', fontweight='bold', fontsize=12)
plt.ylabel('Performance', fontweight='bold', fontsize=12)
# plt.xticks(x)
plt.legend(frameon=False, ncol=1, fontsize=12)
plt.savefig(data_folder + r"\DHA_performance.png", transparent=True, dpi=300)
plt.show()
plt.clf()

# %%
# Diversity
x = range(len(dao_performance))
fig, ax = plt.subplots()
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)

plt.plot(range(len(dao_diversity)), dao_diversity, "k-", label="DAO")
plt.plot(range(len(hierarchy_diversity)), hierarchy_diversity, "k--", label="Hierarchy")
plt.plot(range(len(autonomy_diversity)), autonomy_diversity, "k:", label="Autonomy")
plt.xlabel('Time', fontweight='bold', fontsize=12)
plt.ylabel('Diversity', fontweight='bold', fontsize=12)
# plt.xticks(x)
plt.legend(frameon=False, ncol=1, fontsize=12, prop=legend_properties)
plt.savefig(data_folder + r"\DHA_diversity.png", transparent=True, dpi=300)
plt.show()
plt.clf()

# %%
# Variance
x = range(len(dao_performance))
fig, ax = plt.subplots()
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)
ax.plot(x, dao_variance, "-s", color=nature_orange, label="DAO", markevery=25)
ax.plot(x, hierarchy_variance, "-v", color=nature_green, label="Hierarchy", markevery=25)
ax.plot(x, autonomy_variance, "-o", color=nature_blue, label="Autonomy", markevery=25)
plt.xlabel('Time', fontweight='bold', fontsize=12)
plt.ylabel('Performance Standard Deviation', fontweight='bold', fontsize=10)
ax.legend(frameon=False, ncol=1, fontsize=12, prop=legend_properties)
plt.savefig(data_folder + r"\DHA_variance.png", transparent=True, dpi=300)
plt.show()
plt.clf()

# %%
# CV
x = range(len(dao_cv))
fig, ax = plt.subplots()
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)

ax.plot(x, dao_cv, "-s", color=nature_orange, label="DAO", markevery=25)
# ax.plot(x, hierarchy_cv, "-v", color=nature_green, label="Hierarchy", markevery=25)
# ax.plot(x, autonomy_cv, "-o", color=nature_blue, label="Autonomy", markevery=25)

plt.xlabel('Time', fontweight='bold', fontsize=12)
plt.ylabel('Coefficient of Variation', fontweight='bold', fontsize=12)
ax.legend(frameon=False, ncol=1, fontsize=12, prop=legend_properties)

plt.savefig(data_folder + r"\DHA_cv.png", transparent=True, dpi=300)
plt.show()
plt.clf()

# %%
# Twin
import numpy as np
x = range(len(dao_performance))
legend_properties = {'weight':'bold'}

fig,ax1 = plt.subplots()
ax1.set_xlabel("Time", fontweight='bold', fontsize = 12)
ax1.set_ylabel("Performance", fontweight='bold', color="black", fontsize=12)

ax2=ax1.twinx()
ax2.set_ylabel("Diversity", fontweight='bold', color="black", fontsize=12)

ax2.spines['left'].set_color(nature_orange) # left y-axis
ax1.yaxis.label.set_color(nature_orange) # left y-axis labels
ax1.tick_params(axis='y', colors=nature_orange) # left y-axis params
ax2.spines['right'].set_color(nature_blue) # right y-axis
ax2.yaxis.label.set_color(nature_blue)  # right y-axis labels
ax2.tick_params(axis='y', colors=nature_blue) # right y-axis params

ax2.spines["left"].set_linewidth(1.5)
ax2.spines["right"].set_linewidth(1.5)
ax2.spines["top"].set_linewidth(1.5)
ax2.spines["bottom"].set_linewidth(1.5)

num_markers = 6
# Calculate indices for marker positions
marker_positions = np.linspace(0, len(x) - 1, num=num_markers, dtype=int)

line_1 = ax1.plot(x, dao_performance, "-s", label="DAO", color= nature_orange, markevery=marker_positions)
line_2 = ax1.plot(x, hierarchy_performance, "-v", label="Hierarchy", color= nature_orange, markevery=marker_positions)
line_3 = ax1.plot(x, autonomy_performance, "-o", label="Autonomy (performance)", color= nature_orange, markevery=marker_positions)

line_4 = ax2.plot(x, dao_diversity, "--s", label="DAO", color= nature_blue, markevery=marker_positions)
line_5 = ax2.plot(x, hierarchy_diversity, "--v", label="Hierarchy", color= nature_blue, markevery=marker_positions)
line_6 = ax2.plot(x, autonomy_diversity, "--o", label="Autonomy (diversity)", color= nature_blue, markevery=marker_positions)

lines_1 = line_1 + line_2 + line_3
labs_1 = [l.get_label() for l in lines_1]
ax1.legend(lines_1, labs_1, frameon=False, fontsize=12, loc=(0, 1),  ncol=3, prop=legend_properties)

lines_2 = line_4 + line_5 + line_6
labs_2 = [l.get_label() for l in lines_2]

ax2.legend(lines_2, labs_2, frameon=False, fontsize=12, loc=(0, 1.04),  ncol=3, prop=legend_properties)

plt.savefig(data_folder + r"\DHA_performance_diversity.png", transparent=True, dpi=300, bbox_inches='tight')
plt.show()
plt.clf()

# %%
# Entropy
x = range(len(dao_entropy))
fig, ax = plt.subplots()
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)

ax.plot(x, dao_entropy, "-s", color=nature_orange, label="DAO", markevery=25)
ax.plot(x, hierarchy_entropy, "-v", color=nature_green, label="Hierarchy", markevery=25)
ax.plot(x, autonomy_entropy, "-o", color=nature_blue, label="Autonomy", markevery=25)

plt.xlabel('Time', fontweight='bold', fontsize=12)
plt.ylabel('Entropy', fontweight='bold', fontsize=12)
ax.legend(frameon=False, ncol=1, fontsize=12, prop=legend_properties)

plt.savefig(data_folder + r"\DHA_entropy.png", transparent=True, dpi=300)
plt.show()
plt.clf()
