# %%
import matplotlib.pyplot as plt
import pickle
legend_properties = {'weight':'bold'}

# %%
data_folder = r"E:\data\dao-0310\V4_4\Aggregation"
dao_performance_file = data_folder + r"\dao_performance_across_alpha_time"
hierarchy_performance_file = data_folder + r"\hierarchy_performance_across_alpha_time"
autonomy_performance_file = data_folder + r"\autonomy_performance_across_alpha_time"

dao_diversity_file = data_folder + r"\dao_diversity_across_alpha_time"
hierarchy_diversity_file = data_folder + r"\hierarchy_diversity_across_alpha_time"
autonomy_diversity_file = data_folder + r"\autonomy_diversity_across_alpha_time"

with open(dao_performance_file, 'rb') as infile:
    dao_performance = pickle.load(infile)
with open(hierarchy_performance_file, 'rb') as infile:
    hierarchy_performance = pickle.load(infile)
with open(autonomy_performance_file, 'rb') as infile:
    autonomy_performance = pickle.load(infile)

with open(dao_diversity_file, 'rb') as infile:
    dao_diversity = pickle.load(infile)
with open(hierarchy_diversity_file, 'rb') as infile:
    hierarchy_diversity = pickle.load(infile)
with open(autonomy_diversity_file, 'rb') as infile:
    autonomy_diversity = pickle.load(infile)

# %%
# Define more colors
# NUS two colors
nus_blue = "#003D7C"
nus_orange = "#EF7C00"
# Nature three colors
nature_orange = "#F16C23"
nature_blue = "#2B6A99"
nature_green = "#1B7C3D"
# Morandi six colors
morandi_blue = "#046586"
morandi_green =  "#28A9A1"
morandi_yellow = "#C9A77C"
morandi_orange = "#F4A016"
morandi_pink = "#F6BBC6"
morandi_red = "#E71F19"
morandi_purple = "#B08BEB"
# Others
shallow_grey = "#D3D4D3"
deep_grey = "#A6ABB6"

# %%
# aggregation_level = [1, 3, 5]
x = range(len(dao_performance[0]))
fig, ax = plt.subplots()
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)
plt.plot(x, dao_performance[0], "k-", label="$\\alpha=1$", color=nature_orange)
plt.plot(x, dao_performance[1], "k-", label="$\\alpha=3$", color=nature_blue)
plt.plot(x, dao_performance[2], "k-", label="$\\alpha=5$", color=nature_green)
plt.xlabel('Time', fontweight='bold', fontsize=12)
plt.ylabel('DAO Performance', fontweight='bold', fontsize=12)
plt.legend(frameon=False, ncol=1, fontsize=12)
plt.savefig(data_folder + r"\Aggregation_performance_D.png", transparent=True, dpi=300)
plt.show()
plt.clf()

# %%
# aggregation_level = [1, 3, 5]
x = range(len(hierarchy_performance[0]))
fig, ax = plt.subplots()
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)
plt.plot(x, hierarchy_performance[0], "k-", label="$\\alpha=1$", color=nature_orange)
plt.plot(x, hierarchy_performance[1], "k-", label="$\\alpha=3$", color=nature_blue)
plt.plot(x, hierarchy_performance[2], "k-", label="$\\alpha=5$", color=nature_green)
plt.xlabel('Time', fontweight='bold', fontsize=12)
plt.ylabel('Hierarchy Performance', fontweight='bold', fontsize=12)
plt.legend(frameon=False, ncol=1, fontsize=12)
plt.savefig(data_folder + r"\Aggregation_performance_H.png", transparent=True, dpi=300)
plt.show()
plt.clf()

# %%
# aggregation_level = [1, 3, 5]
x = range(len(hierarchy_performance[0]))
fig, ax = plt.subplots()
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)
plt.plot(x, autonomy_performance[0], "k-", label="$\\alpha=1$", color=nature_orange)
plt.plot(x, autonomy_performance[1], "k-", label="$\\alpha=3$", color=nature_blue)
plt.plot(x, autonomy_performance[2], "k-", label="$\\alpha=5$", color=nature_green)
plt.xlabel('Time', fontweight='bold', fontsize=12)
plt.ylabel('Autonomy Performance', fontweight='bold', fontsize=12)
plt.legend(frameon=False, ncol=1, fontsize=12)
plt.savefig(data_folder + r"\Aggregation_performance_A.png", transparent=True, dpi=300)
plt.show()
plt.clf()

# %%
# Integration
# aggregation_level = [1, 3, 5]
x = range(len(hierarchy_performance[0]))
fig, ax = plt.subplots()
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)
plt.plot(x, dao_performance[0], "k-", color=nature_orange)
plt.plot(x, dao_performance[1], "k--", color=nature_orange)
plt.plot(x, dao_performance[2], "k:", color=nature_orange)

plt.plot(x, hierarchy_performance[0], "k-", color=nature_green)
plt.plot(x, hierarchy_performance[1], "k--", color=nature_green)
plt.plot(x, hierarchy_performance[2], "k:", color=nature_green)

plt.plot(x, autonomy_performance[0], "k-", color=nature_blue)
plt.plot(x, autonomy_performance[1], "k--", color=nature_blue)
plt.plot(x, autonomy_performance[2], "k:", color=nature_blue)
plt.xlabel('Time', fontweight='bold', fontsize=12)
plt.ylabel('Performance', fontweight='bold', fontsize=12)

# Proxy lines for the legend
plt.plot([], [], "k-", label="$\\alpha=1$")
plt.plot([], [], "k--", label="$\\alpha=3$")
plt.plot([], [], "k:", label="$\\alpha=5$")

plt.plot([], [], "k-", label="DAO", color=nature_orange)
plt.plot([], [], "k-", label="Hierarchy", color=nature_green)
plt.plot([], [], "k-", label="Autonomy", color=nature_blue)

plt.legend(frameon=False, ncol=2, fontsize=12)
plt.savefig(data_folder + r"\Aggregation_performance.png", transparent=True, dpi=300)
plt.show()
plt.clf()
