# %%
import matplotlib.pyplot as plt
import pickle

# %%
# Define more colors
# NUS two colors
nus_blue = "#003D7C"
nus_orange = "#EF7C00"
# Nature three colors
nature_orange = "#F16C23"
nature_blue = "#2B6A99"
nature_green = "#1B7C3D"
# Morandi six colors
morandi_blue = "#046586"
morandi_green =  "#28A9A1"
morandi_yellow = "#C9A77C"
morandi_orange = "#F4A016"
morandi_pink = "#F6BBC6"
morandi_red = "#E71F19"
morandi_purple = "#B08BEB"
# Others
shallow_grey = "#D3D4D3"
deep_grey = "#A6ABB6"

# %%
data_folder = r"E:\data\dao-0310-23\Sensitivity\Group_size"
dao_performance_file = data_folder + r"\dao_performance_across_z_time"
hierarchy_performance_file = data_folder + r"\hierarchy_performance_across_z_time"
autonomy_performance_file = data_folder + r"\autonomy_performance_across_z_time"

consensus_performance_file = data_folder + r"\consensus_performance_across_z"
superior_performance_file = data_folder + r"\superior_performance_across_z"

dao_diversity_file = data_folder + r"\dao_diversity_across_z"
hierarchy_diversity_file = data_folder + r"\hierarchy_diversity_across_z"
autonomy_diversity_file = data_folder + r"\autonomy_diversity_across_z"

dao_variance_file = data_folder + r"\dao_variance_across_z"
hierarchy_variance_file = data_folder + r"\hierarchy_variance_across_z"
autonomy_variance_file = data_folder + r"\autonomy_variance_across_z"

with open(dao_performance_file, 'rb') as infile:
    dao_performance = pickle.load(infile)
with open(hierarchy_performance_file, 'rb') as infile:
    hierarchy_performance = pickle.load(infile)
with open(autonomy_performance_file, 'rb') as infile:
    autonomy_performance = pickle.load(infile)

with open(dao_diversity_file, 'rb') as infile:
    dao_diversity = pickle.load(infile)
with open(hierarchy_diversity_file, 'rb') as infile:
    hierarchy_diversity = pickle.load(infile)
with open(autonomy_diversity_file, 'rb') as infile:
    autonomy_diversity = pickle.load(infile)

with open(consensus_performance_file, 'rb') as infile:
    consensus_performance = pickle.load(infile)
with open(superior_performance_file, 'rb') as infile:
    superior_performance = pickle.load(infile)

with open(dao_variance_file, 'rb') as infile:
    dao_variance = pickle.load(infile)
with open(hierarchy_variance_file, 'rb') as infile:
    hierarchy_variance = pickle.load(infile)
with open(autonomy_variance_file, 'rb') as infile:
    autonomy_variance = pickle.load(infile)
# with open(dao_original_performance_file, 'rb') as infile:
#     dao_original_performance = pickle.load(infile)
# with open(hierarchy_original_performance_file, 'rb') as infile:
#     hierarchy_original_performance = pickle.load(infile)
# with open(autonomy_original_performance_file, 'rb') as infile:
#     autonomy_original_performance = pickle.load(infile)

# print(np.array(dao_performance).shape)
# print(dao_performance)

# %%
x = range(len(dao_performance[0]))
group_size_list = [7, 14, 21, 28]
plt.plot(x, dao_performance[0], "-", label="$z=7$", color="k")
plt.plot(x, dao_performance[1], "-", label="$z=14$", color=nature_orange)
plt.plot(x, dao_performance[2], "-", label="$z=21$", color=nature_green)
plt.plot(x, dao_performance[3], "-", label="$z=28$", color=nature_blue)
plt.xlabel('Time', fontweight='bold', fontsize=10)
plt.ylabel('DAO Performance', fontweight='bold', fontsize=10)
plt.legend(frameon=False, ncol=1, fontsize=10)
# plt.savefig(data_folder + r"\DAO_performance_z.png", transparent=False, dpi=300)
plt.show()
plt.clf()

# %%
x = range(len(dao_performance[0]))
group_size_list = [7, 14, 21, 28]
plt.plot(x, hierarchy_performance[0], "-", label="$z=7$", color="k")
plt.plot(x, hierarchy_performance[1], "-", label="$z=14$", color=nature_orange)
plt.plot(x, hierarchy_performance[2], "-", label="$z=21$", color=nature_green)
plt.plot(x, hierarchy_performance[3], "-", label="$z=28$", color=nature_blue)
plt.xlabel('Time', fontweight='bold', fontsize=10)
plt.ylabel('Hierarchy Performance', fontweight='bold', fontsize=10)
plt.legend(frameon=False, ncol=1, fontsize=10)
# plt.savefig(data_folder + r"\DAO_performance_z.png", transparent=False, dpi=300)
plt.show()
plt.clf()

# %%
x = range(len(dao_performance[0]))
group_size_list = [7, 14, 21, 28]
plt.plot(x, autonomy_performance[0], "-", label="$z=7$", color="k")
plt.plot(x, autonomy_performance[1], "-", label="$z=14$", color=nature_orange)
plt.plot(x, autonomy_performance[2], "-", label="$z=21$", color=nature_green)
plt.plot(x, autonomy_performance[3], "-", label="$z=28$", color=nature_blue)
plt.xlabel('Time', fontweight='bold', fontsize=10)
plt.ylabel('Autonomy Performance', fontweight='bold', fontsize=10)
plt.legend(frameon=False, ncol=1, fontsize=10)
# plt.savefig(data_folder + r"\DAO_performance_z.png", transparent=False, dpi=300)
plt.show()
plt.clf()

# %%
x = range(len(dao_performance))
group_size_list = [7, 14, 21, 28]
dao_convergence = [each[-1] for each in dao_performance]
hierarchy_convergence = [each[-1] for each in hierarchy_performance]
autonomy_convergence = [each[-1] for each in autonomy_performance]
fig, ax = plt.subplots()
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)
plt.plot(group_size_list, dao_convergence, "-o", label="DAO", color=nature_orange)
plt.plot(group_size_list, hierarchy_convergence, "-s", label="Hierarchy", color=nature_green)
plt.plot(group_size_list, autonomy_convergence, "-v", label="Autonomy", color=nature_blue)
plt.xlabel('Group Size', fontweight='bold', fontsize=12)
plt.ylabel('Performance', fontweight='bold', fontsize=12)
plt.xticks(group_size_list)
plt.legend(frameon=False, ncol=1, fontsize=12)
plt.title("(a) Performance")
plt.savefig(data_folder + r"\DHA_performance_across_group_size.png", transparent=True, dpi=300)
plt.show()
plt.clf()

# %%
x = range(len(dao_performance))
group_size_list = [7, 14, 21, 28]
# dao_diversity_convergence = [each[-1] for each in dao_diversity]
# hierarchy_diversity_convergence = [each[-1] for each in hierarchy_diversity]
# autonomy_diversity_convergence = [each[-1] for each in autonomy_diversity]
fig, ax = plt.subplots()
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)
plt.plot(group_size_list, dao_diversity, "-o", label="DAO", color=nature_orange)
plt.plot(group_size_list, hierarchy_diversity, "-s", label="Hierarchy", color=nature_green)
plt.plot(group_size_list, autonomy_diversity, "-v", label="Autonomy", color=nature_blue)
plt.xlabel('Group Size', fontweight='bold', fontsize=12)
plt.ylabel('Diversity', fontweight='bold', fontsize=12)
plt.xticks(group_size_list)
plt.legend(frameon=False, ncol=1, fontsize=12)
plt.title("(b) Diversity")
plt.savefig(data_folder + r"\DHA_diversity_across_group_size.png", transparent=True, dpi=300)
plt.show()
plt.clf()
