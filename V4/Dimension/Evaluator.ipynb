# %%
import matplotlib.pyplot as plt
import pickle
import numpy as np
from matplotlib import container

# %%
data_folder = r"E:\data\dao-0310\V4_3\Dimension"
dao_performance_file = data_folder + r"\dao_performance_across_m"
hierarchy_performance_file = data_folder + r"\hierarchy_performance_across_m"
autonomy_performance_file = data_folder + r"\autonomy_performance_across_m"

consensus_performance_file = data_folder + r"\consensus_performance_across_m"
superior_performance_file = data_folder + r"\superior_performance_across_m"

dao_diversity_file = data_folder + r"\dao_diversity_across_m"
hierarchy_diversity_file = data_folder + r"\hierarchy_diversity_across_m"
autonomy_diversity_file = data_folder + r"\autonomy_diversity_across_m"

dao_variance_file = data_folder + r"\dao_variance_across_m"
hierarchy_variance_file = data_folder + r"\hierarchy_variance_across_m"
autonomy_variance_file = data_folder + r"\autonomy_variance_across_m"

dao_original_performance_file = data_folder + r"\dao_performance_across_m_time"
hierarchy_original_performance_file = data_folder + r"\hierarchy_performance_across_m_time"
autonomy_original_performance_file = data_folder + r"\autonomy_performance_across_m_time"

with open(dao_performance_file, 'rb') as infile:
    dao_performance = pickle.load(infile)
with open(hierarchy_performance_file, 'rb') as infile:
    hierarchy_performance = pickle.load(infile)
with open(autonomy_performance_file, 'rb') as infile:
    autonomy_performance = pickle.load(infile)

with open(dao_diversity_file, 'rb') as infile:
    dao_diversity = pickle.load(infile)
with open(hierarchy_diversity_file, 'rb') as infile:
    hierarchy_diversity = pickle.load(infile)
with open(autonomy_diversity_file, 'rb') as infile:
    autonomy_diversity = pickle.load(infile)

with open(consensus_performance_file, 'rb') as infile:
    consensus_performance = pickle.load(infile)
with open(superior_performance_file, 'rb') as infile:
    superior_performance = pickle.load(infile)

with open(dao_variance_file, 'rb') as infile:
    dao_variance = pickle.load(infile)
with open(hierarchy_variance_file, 'rb') as infile:
    hierarchy_variance = pickle.load(infile)
with open(autonomy_variance_file, 'rb') as infile:
    autonomy_variance = pickle.load(infile)

with open(dao_original_performance_file, 'rb') as infile:
    dao_original_performance = pickle.load(infile)
with open(hierarchy_original_performance_file, 'rb') as infile:
    hierarchy_original_performance = pickle.load(infile)
with open(autonomy_original_performance_file, 'rb') as infile:
    autonomy_original_performance = pickle.load(infile)

print(np.array(dao_performance).shape)
print(dao_performance)
# Out:
# (4,)
# [0.7439861904761906, 0.7128820634920633, 0.6935821428571424, 0.6767183809523809]

# %%
x = range(len(dao_performance))
# m_list = [60, 90, 120, 150]
plt.plot(range(len(dao_performance)), dao_performance, "r-", label="DAO")
plt.plot(range(len(hierarchy_performance)), hierarchy_performance, "b-", label="Hierarchy")
plt.plot(range(len(autonomy_performance)), autonomy_performance, "k-", label="Autonomy")
plt.xlabel('Time', fontweight='bold', fontsize=10)
plt.ylabel('Performance', fontweight='bold', fontsize=10)
# plt.xticks(x)
plt.legend(frameon=False, ncol=1, fontsize=10)
plt.savefig(data_folder + r"\DHA_performance.png", transparent=False, dpi=200)
plt.show()
plt.clf()

# %%
# DAO
# m_list = [60, 90, 120, 150]
x = range(len(dao_original_performance[0]))
plt.plot(x, dao_original_performance[0], "r-", label="$m=60$")
plt.plot(x, dao_original_performance[1], "b-", label="$m=90$")
plt.plot(x, dao_original_performance[2], "y-", label="$m=120$")
plt.plot(x, dao_original_performance[3], "g-", label="$m=150$")
plt.xlabel('Time', fontweight='bold', fontsize=10)
plt.ylabel('Performance', fontweight='bold', fontsize=10)
# plt.xticks(x)
plt.legend(frameon=False, ncol=1, fontsize=10)
plt.savefig(data_folder + r"\DAO_performance_across_m_time.png", transparent=False, dpi=200)
plt.show()
plt.clf()

# %%
# DAO
# m_list = [60, 90, 120, 150]
x = range(len(dao_original_performance[0]))
plt.plot(x, dao_original_performance[0], "r-", label="DAO")
plt.plot(x, hierarchy_original_performance[0], "b-", label="Hierarchy")
plt.plot(x, autonomy_original_performance[0], "y-", label="Autonomy")
plt.xlabel('Time', fontweight='bold', fontsize=10)
plt.ylabel('Performance', fontweight='bold', fontsize=10)
# plt.xticks(x)
plt.legend(frameon=False, ncol=1, fontsize=10)
plt.savefig(data_folder + r"\DHA_performance_m60.png", transparent=False, dpi=200)
plt.show()
plt.clf()

# %%
# DAO
# m_list = [60, 90, 120, 150]
x = range(len(dao_original_performance[1]))
plt.plot(x, dao_original_performance[1], "r-", label="DAO")
plt.plot(x, hierarchy_original_performance[1], "b-", label="Hierarchy")
plt.plot(x, autonomy_original_performance[1], "y-", label="Autonomy")
plt.xlabel('Time', fontweight='bold', fontsize=10)
plt.ylabel('Performance', fontweight='bold', fontsize=10)
# plt.xticks(x)
plt.legend(frameon=False, ncol=1, fontsize=10)
plt.savefig(data_folder + r"\DHA_performance_m90.png", transparent=False, dpi=200)
plt.show()
plt.clf()

# %%
# DAO
# m_list = [60, 90, 120, 150]
x = range(len(dao_original_performance[2]))
plt.plot(x, dao_original_performance[2], "r-", label="DAO")
plt.plot(x, hierarchy_original_performance[2], "b-", label="Hierarchy")
plt.plot(x, autonomy_original_performance[2], "y-", label="Autonomy")
plt.xlabel('Time', fontweight='bold', fontsize=10)
plt.ylabel('Performance', fontweight='bold', fontsize=10)
# plt.xticks(x)
plt.legend(frameon=False, ncol=1, fontsize=10)
plt.savefig(data_folder + r"\DHA_performance_m120.png", transparent=False, dpi=200)
plt.show()
plt.clf()

# %%
# DAO
# m_list = [60, 90, 120, 150]
x = range(len(dao_original_performance[3]))
plt.plot(x, dao_original_performance[3], "r-", label="DAO")
plt.plot(x, hierarchy_original_performance[3], "b-", label="Hierarchy")
plt.plot(x, autonomy_original_performance[3], "y-", label="Autonomy")
plt.xlabel('Time', fontweight='bold', fontsize=10)
plt.ylabel('Performance', fontweight='bold', fontsize=10)
# plt.xticks(x)
plt.legend(frameon=False, ncol=1, fontsize=10)
plt.savefig(data_folder + r"\DHA_performance_m150.png", transparent=False, dpi=200)
plt.show()
plt.clf()
