# %%
import matplotlib.pyplot as plt
import pickle
import numpy as np
legend_properties = {'weight':'bold'}

# %%
data_folder = r"E:\data\dao-0310\V4_3\Incentive"
dao_performance_file = data_folder + r"\dao_performance"
consensus_performance_file = data_folder + r"\dao_consensus_performance"
dao_diversity_file = data_folder + r"\dao_diversity"
dao_variance_file = data_folder + r"\dao_variance"
dao_percentile_10_file = data_folder + r"\dao_percentile_10"
dao_percentile_90_file = data_folder + r"\dao_percentile_90"
dao_gini_file = data_folder + r"\dao_gini"
dao_original_performance_file = data_folder + r"\dao_original_performance"

with open(dao_performance_file, 'rb') as infile:
    dao_performance = pickle.load(infile)
with open(dao_diversity_file, 'rb') as infile:
    dao_diversity = pickle.load(infile)
with open(dao_variance_file, 'rb') as infile:
    dao_variance = pickle.load(infile)
with open(dao_gini_file, 'rb') as infile:
    dao_gini = pickle.load(infile)
with open(consensus_performance_file, 'rb') as infile:
    consensus_performance = pickle.load(infile)

with open(dao_original_performance_file, 'rb') as infile:
    dao_original_performance = pickle.load(infile)

# %%
# Define more colors
# NUS two colors
nus_blue = "#003D7C"
nus_orange = "#EF7C00"
# Nature three colors
nature_orange = "#F16C23"
nature_blue = "#2B6A99"
nature_green = "#1B7C3D"
# Morandi six colors
morandi_blue = "#046586"
morandi_green =  "#28A9A1"
morandi_yellow = "#C9A77C"
morandi_orange = "#F4A016"
morandi_pink = "#F6BBC6"
morandi_red = "#E71F19"
morandi_purple = "#B08BEB"
# Others
shallow_grey = "#D3D4D3"
deep_grey = "#A6ABB6"

# %%
# Performance
# incentive_list = [0, 1, 10, 100]
x = range(len(dao_performance[0]))
fig, ax = plt.subplots()
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)
plt.plot(x, dao_performance[0], "k-", label='$\\gamma=0$')
plt.plot(x, dao_performance[1], "k:", label='$\\gamma=1$')
plt.plot(x, dao_performance[2], "k--", label='$\\gamma=10$')
plt.plot(x, dao_performance[3], "k-.", label='$\\gamma=100$')
plt.xlabel('Time', fontweight='bold', fontsize=12)
plt.ylabel('Performance', fontweight='bold', fontsize=12)
# plt.xticks(x)
plt.legend(frameon=False, ncol=1, fontsize=12, prop=legend_properties)
plt.savefig(data_folder + r"\Incentive_performance.png", transparent=False, dpi=200)
plt.show()
plt.clf()

# %%
# Diversity
# incentive_list = [0, 1, 10, 100]
x = range(len(dao_performance[0]))
fig, ax = plt.subplots()
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)
plt.plot(x, dao_diversity[0], "k-", label='$\\gamma=0$')
plt.plot(x, dao_diversity[1], "k:", label='$\\gamma=11$')
plt.plot(x, dao_diversity[2], "k--", label='$\\gamma=10$')
plt.plot(x, dao_diversity[3], "k-.", label='$\\gamma=100$')
plt.xlabel('Time', fontweight='bold', fontsize=12)
plt.ylabel('Diversity', fontweight='bold', fontsize=12)
# plt.xticks(x)
plt.legend(frameon=False, ncol=1, fontsize=12, prop=legend_properties)
plt.savefig(data_folder + r"\Incentive_diversity.png", transparent=True, dpi=200)
plt.show()
plt.clf()

# %%
# Gini
x = range(len(dao_performance[0]))
fig, ax = plt.subplots()
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)
plt.plot(x, dao_gini[0], "k-", label='$\\gamma=0$')
plt.plot(x, dao_gini[1], "k:", label='$\\gamma=1$')
plt.plot(x, dao_gini[2], "k--", label='$\\gamma=10$')
plt.plot(x, dao_gini[3], "k-.", label='$\\gamma=100$')
plt.xlabel('Time', fontweight='bold', fontsize=12)
plt.ylabel('Gini', fontweight='bold', fontsize=12)
# plt.xticks(x)
plt.legend(frameon=False, ncol=1, fontsize=12, prop=legend_properties)
plt.savefig(data_folder + r"\Incentive_gini.png", transparent=True, dpi=200)
plt.show()
plt.clf()

# %%
# Variance
x = range(len(dao_performance[0]))
fig, ax = plt.subplots()
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)
plt.plot(x, dao_variance[0], "k-", label='$\\gamma=0$', color=nature_blue)
plt.plot(x, dao_variance[1], "k-", label='$\\gamma=10$', color=nature_green)
plt.plot(x, dao_variance[2], "k-", label='$\\gamma=100$', color=nature_orange)
plt.plot(x, dao_variance[3], "k-", label='$\\gamma=1000$', color=morandi_red)
plt.xlabel('Time', fontweight='bold', fontsize=12)
plt.ylabel('Variance', fontweight='bold', fontsize=12)
# plt.xticks(x)
plt.legend(frameon=False, ncol=1, fontsize=12, prop=legend_properties)
plt.savefig(data_folder + r"\Incentive_variance.png", transparent=True, dpi=200)
plt.show()
plt.clf()

# %%
# Twin
import numpy as np
# x = range(len(dao_performance))

nusblue = "#003D7C"
nusorange = "#EF7C00"
legend_properties = {'weight':'bold'}

fig,ax1 = plt.subplots()
ax1.set_xlabel("Time", fontweight='bold', fontsize = 12)
ax1.set_ylabel("Performance", fontweight='bold', color="black", fontsize=12)

ax2=ax1.twinx()
ax2.set_ylabel("Diversity", fontweight='bold', color="black", fontsize=12)

ax2.spines["left"].set_linewidth(1.5)
ax2.spines["right"].set_linewidth(1.5)
ax2.spines["top"].set_linewidth(1.5)
ax2.spines["bottom"].set_linewidth(1.5)
# Colors
ax2.spines['left'].set_color(nature_orange) # left spines
ax2.spines['right'].set_color(nature_blue) # right spines
ax1.yaxis.label.set_color(nature_orange)  # left label
ax1.tick_params(axis='y', colors=nature_orange) # left tick
ax2.yaxis.label.set_color(nature_blue) # right label
ax2.tick_params(axis='y', colors=nature_blue) # right tick

line_1 = ax1.plot(x, dao_performance[0], "k-", color=nature_orange, label='$\\gamma=0$')
line_2 = ax1.plot(x, dao_performance[1], "k:", color = nature_orange, label='$\\gamma=1$')
line_3 = ax1.plot(x, dao_performance[2], "k--", color = nature_orange, label='$\\gamma=10$')
line_4 = ax1.plot(x, dao_performance[3], "k-.", color = nature_orange, label='$\\gamma=100$')

line_5 = ax2.plot(x, dao_diversity[0], "k-", color= nature_blue, label='$\\gamma=0$')
line_6 = ax2.plot(x, dao_diversity[1], "k:", color = nature_blue, label='$\\gamma=1$')
line_7 = ax2.plot(x, dao_diversity[2], "k--", color = nature_blue, label='$\\gamma=10$')
line_8 = ax2.plot(x, dao_diversity[3], "k-.", color = nature_blue, label='$\\gamma=100$')

lines_1 = line_1 + line_2 + line_3 + line_4
labs_1 = [l.get_label() for l in lines_1]
ax1.legend(lines_1, labs_1, frameon=False, fontsize=12, loc=(0.1, 0.50),  ncol=len(lines_1), prop=legend_properties)

lines_2 = line_5 + line_6 + line_7 + line_8
labs_2 = [l.get_label() for l in lines_2]

ax2.legend(lines_2, labs_2, frameon=False, fontsize=12, loc=(0.1, 0.45),  ncol=len(lines_2), prop=legend_properties)

plt.savefig(data_folder + r"\Incentive_performance_diversity.png", transparent=True, dpi=200, bbox_inches='tight')
plt.show()
plt.clf()
