# %%
import matplotlib.pyplot as plt
import pickle
import numpy as np
legend_properties = {'weight':'bold'}

# %%
data_folder = r"E:\data\dao-0310-23\Topology\DHA"
isolation_file_1 = data_folder + r"\num_isolated_node_across_autonomy_1"
subnetwork_file_1 = data_folder + r"\num_subnetwork_across_autonomy_1"
node_file_1 = data_folder + r"\num_isolated_node_across_autonomy_1"
distance_file_1 = data_folder + r"\distance_across_autonomy_1"
with open(isolation_file_1, 'rb') as infile:
    isolation_1 = pickle.load(infile)
with open(subnetwork_file_1, 'rb') as infile:
    subnetwork_1 = pickle.load(infile)
with open(node_file_1, 'rb') as infile:
    node_1 = pickle.load(infile)
with open(distance_file_1, 'rb') as infile:
    distance_1 = pickle.load(infile)

isolation_file_2 = data_folder + r"\num_isolated_node_across_autonomy_2"
subnetwork_file_2 = data_folder + r"\num_subnetwork_across_autonomy_2"
node_file_2 = data_folder + r"\num_isolated_node_across_autonomy_2"
distance_file_2 = data_folder + r"\distance_across_autonomy_2"
with open(isolation_file_2, 'rb') as infile:
    isolation_2 = pickle.load(infile)
with open(subnetwork_file_2, 'rb') as infile:
    subnetwork_2 = pickle.load(infile)
with open(node_file_2, 'rb') as infile:
    node_2 = pickle.load(infile)
with open(distance_file_2, 'rb') as infile:
    distance_2 = pickle.load(infile)

# %%
# Define more colors
# NUS two colors
nus_blue = "#003D7C"
nus_orange = "#EF7C00"
# Nature three colors
nature_orange = "#F16C23"
nature_blue = "#2B6A99"
nature_green = "#1B7C3D"
# Morandi six colors
morandi_blue = "#046586"
morandi_green =  "#28A9A1"
morandi_yellow = "#C9A77C"
morandi_orange = "#F4A016"
morandi_pink = "#F6BBC6"
morandi_red = "#E71F19"
morandi_purple = "#B08BEB"
# Others
shallow_grey = "#D3D4D3"
deep_grey = "#A6ABB6"

# %%
# All Isolation 1
x = np.arange(0.02, 1.02, 0.02).tolist()
fig, ax = plt.subplots()
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)
plt.plot(x, isolation_1, "k-", label="Isolation")
# plt.plot(x, subnetwork, "k--", label="Sub-network")
# plt.plot(x, node, "k:", label="Isolated Node")
plt.xlabel('Autonomy', fontweight='bold', fontsize=12)
plt.ylabel('Number', fontweight='bold', fontsize=12)
# plt.xticks(x)
plt.legend(frameon=False, ncol=1, fontsize=12)
plt.savefig(data_folder + r"\isolation_across_autonomy_1.png", transparent=True, dpi=300)
plt.show()
plt.clf()

# %%
# All Isolation 2
x = np.arange(0.02, 1.02, 0.02).tolist()
fig, ax = plt.subplots()
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)
plt.plot(x, isolation_2, "k-", label="Isolation")
# plt.plot(x, subnetwork, "k--", label="Sub-network")
# plt.plot(x, node, "k:", label="Isolated Node")
plt.xlabel('Autonomy', fontweight='bold', fontsize=12)
plt.ylabel('Number', fontweight='bold', fontsize=12)
# plt.xticks(x)
plt.legend(frameon=False, ncol=1, fontsize=12)
plt.savefig(data_folder + r"\isolation_across_autonomy_2.png", transparent=True, dpi=300)
plt.show()
plt.clf()

# %%
# Topology-only Network vs. Attribute-enriched Network:
# All Isolation 2
x = np.arange(0.02, 1.02, 0.02).tolist()
fig, ax = plt.subplots()
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)
plt.plot(x, isolation_1, "-", label="Fitness oriented")
plt.plot(x, isolation_2, "--", label="Topology only")
# plt.plot(x, node, "k:", label="Isolated Node")
plt.xlabel('Autonomy', fontweight='bold', fontsize=12)
plt.ylabel('Subnetwork Number', fontweight='bold', fontsize=12)
# plt.xticks(x)
plt.legend(frameon=False, ncol=1, fontsize=12)
plt.savefig(data_folder + r"\isolation_across_autonomy_3.png", transparent=True, dpi=300)
plt.show()
plt.clf()

# %%
# Topology-only Network vs. Attribute-enriched Network:
# All Isolation 2
x = np.arange(0.02, 1.02, 0.02).tolist()
fig, ax = plt.subplots()
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)
plt.plot(x, distance_1, "k-", label="Fitness oriented")
plt.plot(x, distance_2, "k--", label="Topology only")
# plt.plot(x, node, "k:", label="Isolated Node")
plt.xlabel('Autonomy', fontweight='bold', fontsize=12)
plt.ylabel('Subnetwork Number', fontweight='bold', fontsize=12)
# plt.xticks(x)
plt.legend(frameon=False, ncol=1, fontsize=12)
plt.savefig(data_folder + r"\isolation_across_autonomy_3.png", transparent=True, dpi=300)
plt.show()
plt.clf()

# %%
# Twin
import numpy as np
x = np.arange(0.02, 1.02, 0.02).tolist()
legend_properties = {'weight':'bold'}

fig,ax1 = plt.subplots()
ax1.set_xlabel("Autonomous Degree", fontweight='bold', fontsize = 12)
ax1.set_ylabel("Number of Sub-Network", fontweight='bold', color="black", fontsize=12)

ax2=ax1.twinx()
ax2.set_ylabel("The Shortest Path Length", fontweight='bold', color="black", fontsize=12)

ax2.spines['left'].set_color(nature_orange) # left y-axis
ax1.yaxis.label.set_color(nature_orange) # left y-axis labels
ax1.tick_params(axis='y', colors=nature_orange) # left y-axis params
ax2.spines['right'].set_color(nature_blue) # right y-axis
ax2.yaxis.label.set_color(nature_blue)  # right y-axis labels
ax2.tick_params(axis='y', colors=nature_blue) # right y-axis params

ax2.spines["left"].set_linewidth(1.5)
ax2.spines["right"].set_linewidth(1.5)
ax2.spines["top"].set_linewidth(1.5)
ax2.spines["bottom"].set_linewidth(1.5)

num_markers = 10
# Calculate indices for marker positions
marker_positions = np.linspace(0, len(x) - 1, num=num_markers, dtype=int)

line_1 = ax1.plot(x, isolation_1, "-", color=nature_orange, label="Undirected")
line_2 = ax1.plot(x, isolation_2, "--", color = nature_orange, label="Fitness-directed")

line_3 = ax2.plot(x, distance_1, "-s", color= nature_blue, label="Undirected", markevery=marker_positions)
line_4 = ax2.plot(x, distance_2, "--v", color = nature_blue, label="Fitness-directed", markevery=marker_positions)

lines_1 = line_1 + line_2
labs_1 = [l.get_label() for l in lines_1]
ax1.legend(lines_1, labs_1, frameon=False, fontsize=12, loc=(0, 0.26),  ncol=3, prop=legend_properties)

lines_2 =  line_3 + line_4
labs_2 = [l.get_label() for l in lines_1]

ax2.legend(lines_2, labs_2, frameon=False, fontsize=12, loc=(0, 0.20),  ncol=3, prop=legend_properties)

plt.savefig(data_folder + r"\Autonomy_2_Isolation.png", transparent=True, dpi=300, bbox_inches='tight')
plt.show()
plt.clf()
